# %% [markdown]
# # Data Understanding

# %%
import pandas as pd

df = pd.read_csv(
    '../data/raw/bank-full.csv',
    sep=';'
)

print(df.shape)

# %%
df.head()

# %%
df.info()

# %%
df.describe(include='all').T

# %%
df.isnull().sum()

# %%
df['y'].value_counts()
